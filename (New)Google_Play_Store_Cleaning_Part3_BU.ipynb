# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
#%matplotlib

# %%
file_path = "https://raw.githubusercontent.com/JD-DataScienceProjects/Careerera_Projects/main/googleplaystore.csv"

# %% [markdown]
# # Google Play Store Dataset - Expected Data Dictionary
#
# | Column Name     | Description                                            | Expected Data Type     | Example                            | Notes                                                      |
# |-----------------|--------------------------------------------------------|------------------------|------------------------------------|------------------------------------------------------------|
# | `App`           | The name of the application.                           | String                 | "Photo Editor & Candy Camera & Grid & ScrapBook" |                                                            |
# | `Category`      | The category of the application.                       | String (Categorical)   | "ART_AND_DESIGN"                   |                                                            |
# | `Rating`        | The overall user rating of the application.            | Float                  | 4.1                                | Ratings are typically in a 1-5 range, with decimal points. |
# | `Reviews`       | The number of user reviews.                            | Integer                | 159                                | Represents the count of user reviews.                      |
# | `Size`          | The size of the application.                           | String or Float        | "19M" or 19.0                      | Can be a numerical value (in MB/GB) or a string (Varies with device). |
# | `Installs`      | The number of times the application has been installed.| Integer                | 10000                              | Typically a numerical value without symbols.               |
# | `Type`          | Whether the app is free or paid.                       | String (Categorical)   | "Free"                             | Common values are "Free" or "Paid".                        |
# | `Price`         | The price of the application.                          | Float                  | 0.0                                | Represents the price in dollars.                           |
# | `Content Rating`| Age group the application is targeted at.              | String (Categorical)   | "Everyone"                         | Common values include "Everyone", "Teen", etc.             |
# | `Genres`        | The genre of the application.                          | String                 | "Art & Design"                     | Can include multiple genres separated by a semicolon.      |
# | `Last Updated`  | The date when the application was last updated on the Play Store. | Date        | "January 7, 2018"                  | Typically in a date format.                                |
# | `Current Ver`   | The current version of the application.                | String                 | "1.0.0"                            | Version format can vary significantly between apps.        |
# | `Android Ver`   | The minimum Android version required to run the application. | String             | "4.0.3 and up"                     | Describes the range of compatible Android versions.        |

# %%
df = pd.read_csv(file_path)

# %%
df_copy = df

# %%
df.head()
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone  \
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver
# 0               Art & Design   January 7, 2018               1.0.0  \
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone  \
# ...

# %%
df.tail()
# Out:
#                                                  App             Category
# 10836                               Sya9a Maroc - FR               FAMILY  \
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price
# 10836     4.5      38                 53M       5,000+  Free     0  \
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver
# ...

# %%
df.Reviews.unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Reviews'].dtypes
# Out:
# dtype('O')

# %%
df['Reviews'][0]
# Out:
# '159'

# %%
type(df['Reviews'][0])
# Out:
# str

# %%
df[df.Reviews.str.isnumeric()]
# Out:
#                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M  \
#
#          Size Installs Type     Price Content Rating             Genres
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018  \
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.drop(10472, axis = 0, inplace = True)
df.shape
# Out:
# (10840, 13)

# %%
df.iloc[10471:10476]
# Out:
#                            App         Category  Rating Reviews  Size
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k  \
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
# 10476    Lennox iComfort Wi-Fi        LIFESTYLE     3.0     552  7.6M
#
#           Installs  Type Price Content Rating           Genres
# 10471     100,000+  Free     0       Everyone  Personalization  \
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
# 10476      50,000+  Free     0       Everyone        Lifestyle
#
#             Last Updated Current Ver   Android Ver
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# ...

# %%
#reset the index after dropping a row
df.reset_index(drop=True, inplace =  True)

# %%
df.iloc[10471:10476]
# Out:
#                            App         Category  Rating Reviews  Size
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k  \
# 10472  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10473             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10474         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
# 10475    Lennox iComfort Wi-Fi        LIFESTYLE     3.0     552  7.6M
#
#           Installs  Type Price Content Rating           Genres
# 10471     100,000+  Free     0       Everyone  Personalization  \
# 10472  10,000,000+  Free     0       Everyone            Tools
# 10473       1,000+  Free     0       Everyone    Communication
# 10474      50,000+  Free     0       Everyone            Tools
# 10475      50,000+  Free     0       Everyone        Lifestyle
#
#             Last Updated Current Ver   Android Ver
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10472     August 7, 2018     6.06.14    4.4 and up
# ...

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df['Reviews'] = df['Reviews'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.0+ MB

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating
# 0      159   19M      10,000+  Free     0       Everyone  \
# ...

# %%
df["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10835                   53M
# 10836                  3.6M
# 10837                  9.5M
# 10838    Varies with device
# 10839                   19M
# Name: Size, Length: 10840, dtype: object

# %%
df["Size"].dtype
# Out:
# dtype('O')

# %%
df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# ### Convert to Only One Unit
#
# Conversion Factor: 1 MB = 1024 kb --> approximate to 1 MB ~ 1000 kb

# %%
df["Size"][0]
# Out:
# '19M'

# %%
#note that the variable is currently an object so we can use str methods
df['Size'] = df["Size"].str.replace("M","000")

# %%
df['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201k', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
df['Size']= df['Size'].str.replace("k","")

# %%
df['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
df.iloc[10838]
# Out:
# App               The SCP Foundation DB fr nn5n
# Category                    BOOKS_AND_REFERENCE
# Rating                                      4.5
# Reviews                                     114
# Size                         Varies with device
# Installs                                 1,000+
# Type                                       Free
# Price                                         0
# Content Rating                       Mature 17+
# Genres                        Books & Reference
# Last Updated                   January 19, 2015
# Current Ver                  Varies with device
# Android Ver                  Varies with device
# Name: 10838, dtype: object

# %%
df.iloc[10835:10850]
# Out:
#                                                  App             Category
# 10835                               Sya9a Maroc - FR               FAMILY  \
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price
# 10835     4.5       38               53000       5,000+  Free     0  \
# 10836     5.0        4              3.6000         100+  Free     0
# 10837     NaN        3              9.5000       1,000+  Free     0
# 10838     4.5      114  Varies with device       1,000+  Free     0
# 10839     4.5   398307               19000  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver
# ...

# %%
df["Size"]=df["Size"].str.replace("Varies with device", str(np.nan))

# %%
df['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df['Size'].dtypes
# Out:
# dtype('O')

# %%
df['Size'] = df['Size'].astype(float)

# %%
df['Size'].dtypes
# Out:
# dtype('float64')

# %%
df['Size'].head()
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# Name: Size, dtype: float64

# %%
df['Size'][2]
# Out:
# 8.7

# %%
for i in df['Size']:
    if i < 10:
        df["Size"] = df["Size"].replace(i, i*1000)

# %%
df.sort_values(by = "Size")
# Out:
#                                                      App             Category
# 2875                        InstaCam - Camera for Selfie          PHOTOGRAPHY  \
# 3172                            Hipmunk Hotels & Flights     TRAVEL_AND_LOCAL
# 5086   Apps for SportsBєtting.ag - Bitcoin Welcome here!               SPORTS
# 1593                                            w UN map            LIFESTYLE
# 10131                                         EZ Display         PRODUCTIVITY
# ...                                                  ...                  ...
# 10712  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10724                                          Posta App  MAPS_AND_NAVIGATION
# 10764                    Chat For Strangers - Video Chat               SOCIAL
# 10825          Frim: get new friends on local chat rooms               SOCIAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
df['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+03, 2.50e+04, 2.80e+03, 5.60e+03,
#        2.90e+04, 3.30e+04, 3.10e+03, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+03, 5.50e+03, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+03, 7.00e+03, 2.30e+04, 6.00e+03, 6.10e+03,
#        4.60e+03, 9.20e+03, 5.20e+03, 1.10e+04, 2.40e+04,      nan,
#        9.40e+03, 1.50e+04, 1.00e+04, 1.20e+03, 2.60e+04, 8.00e+03,
#        7.90e+03, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+03, 5.70e+03, 8.60e+03, 2.40e+03, 2.70e+04, 2.50e+03,
#        1.60e+04, 3.40e+03, 8.90e+03, 3.90e+03, 2.90e+03, 3.80e+04,
#        3.20e+04, 5.40e+03, 1.80e+04, 1.10e+03, 2.20e+03, 4.50e+03,
#        9.80e+03, 5.20e+04, 9.00e+03, 6.70e+03, 3.00e+04, 2.60e+03,
#        7.10e+03, 3.70e+03, 2.20e+04, 7.40e+03, 6.40e+03, 3.20e+03,
#        8.20e+03, 9.90e+03, 4.90e+03, 9.50e+03, 5.00e+03, 5.90e+03,
#        1.30e+04, 7.30e+04, 6.80e+03, 3.50e+03, 4.00e+03, 2.30e+03,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 1.0+ MB

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'][0]
# Out:
# '0'

# %%
#we can write a code to remove the unwanted characters
chars = ['+', ',', '$']
feat_list = ["Installs", "Price"]
for char in chars:
    for feat in feat_list:
        df[feat]= df[feat].str.replace(char, "")

# %%
df["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df["Installs"]=df["Installs"].astype(int)

# %%
df["Price"]=df["Price"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1016.4+ KB

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10835       July 25, 2017
# 10836        July 6, 2018
# 10837    January 20, 2017
# 10838    January 19, 2015
# 10839       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df['Last Updated'][0]
# Out:
# 'January 7, 2018'

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 1016.4+ KB

# %%
df['Last Updated'].dt.day
# Out:
# 0         7
# 1        15
# 2         1
# 3         8
# 4        20
#          ..
# 10835    25
# 10836     6
# 10837    20
# 10838    19
# 10839    25
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df['Last Updated'].dt.month
# Out:
# 0        1
# 1        1
# 2        8
# 3        6
# 4        6
#         ..
# 10835    7
# 10836    7
# 10837    1
# 10838    1
# 10839    7
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df['Last Updated'].dt.year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 10835    2017
# 10836    2018
# 10837    2017
# 10838    2015
# 10839    2018
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df['Android Ver']
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10835            4.1 and up
# 10836            4.1 and up
# 10837            2.2 and up
# 10838    Varies with device
# 10839    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
df['Android Ver'].dtypes
# Out:
# dtype('O')

# %%
df['Android Ver']=df['Android Ver'].str.replace("and up", "")

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        'Varies with device', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ',
#        '2.1 ', '7.0 ', '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ',
#        '4.4W ', '7.1 ', '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ',
#        '2.0.1 ', '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df['Android Ver']=df['Android Ver'].str.replace("NaN", str(np.nan))

# %%
#removed "and up" so the minimum version is listed
df['Android Ver'].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        'Varies with device', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ',
#        '2.1 ', '7.0 ', '5.1 ', '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ',
#        '4.4W ', '7.1 ', '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ',
#        '2.0.1 ', '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df3 = pd.read_csv(file_path)

# %%
df3['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 1016.4+ KB

# %%
df.to_csv("clean_GPS_012824", index = False)

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews     Size  Installs  Type  Price Content Rating
# 0      159  19000.0     10000  Free    0.0       Everyone  \
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2  \
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated('App')]
# Out:
#                                       App       Category  Rating  Reviews
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805  \
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres
# ...

# %%
df.drop_duplicates(subset = ['App'], keep = 'first', inplace = True)

# %%
df.shape
# Out:
# (9659, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int32
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int32
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 981.0+ KB

# %%
nums = [cols for cols in df.columns if df[cols].dtype != "O"]
cat = [cols for cols in df.columns if df[cols].dtype == "O"]

# %%
nums
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated']

# %%
nums.pop()
# Out:
# 'Last Updated'

# %%
nums
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %%
cat
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
df[nums].describe()
# Out:
#             Rating       Reviews           Size      Installs        Price
# count  8196.000000  9.659000e+03    8432.000000  9.659000e+03  9659.000000
# mean      4.173243  2.165926e+05   20384.448648  7.777507e+06     1.099299
# std       0.536625  1.831320e+06   21835.148282  5.375828e+07    16.852152
# min       1.000000  0.000000e+00      10.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01    4500.000000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02   12000.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04   28000.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09   400.000000

# %%
df[cat]
# Out:
#                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[nums].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rating    8196 non-null   float64
#  1   Reviews   9659 non-null   int32
#  2   Size      8432 non-null   float64
#  3   Installs  9659 non-null   int32
#  4   Price     9659 non-null   float64
# dtypes: float64(3), int32(2)
# memory usage: 377.3 KB

# %%
df[cat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Type            9658 non-null   object
#  3   Content Rating  9659 non-null   object
#  4   Genres          9659 non-null   object
#  5   Current Ver     9651 non-null   object
#  6   Android Ver     9657 non-null   object
# dtypes: object(7)
# memory usage: 603.7+ KB

# %%
#create a function to return skewness of all num cols
def calc_skewness(df, num_cols):
    skewness_list = []


    #calculate the skewness
    for col in num_cols:
        skewness = df[col].skew()
        skewness_list.append({"Feature": col, 'Skewness': skewness})

    skewness_df = pd.DataFrame(skewness_list)


    # return the data frame and sort by absolute value of skewness
    return skewness_df.sort_values(by = 'Skewness', key = abs, ascending = False)

# %%
skewness_df = calc_skewness(df, nums)

# %%
skewness_df
# Out:
#     Feature   Skewness
# 1   Reviews  26.573459
# 4     Price  22.530325
# 3  Installs  15.037532
# 0    Rating  -1.743965
# 2      Size   1.644825

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int32
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int32
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(2), object(7)
# memory usage: 981.0+ KB

# %%
def conv_to_cat(df):
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col]=df[col].astype('category')
    return df

# %%
conv_to_cat(df)
# Out:
#                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   category
#  1   Category        9659 non-null   category
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int32
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int32
#  6   Type            9658 non-null   category
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   category
#  9   Genres          9659 non-null   category
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   category
#  12  Android Ver     9657 non-null   category
# dtypes: category(7), datetime64[ns](1), float64(3), int32(2)
# memory usage: 965.6 KB

# %%
from sklearn.impute import SimpleImputer

def impute_vals(df, num_cols, cat_cols):
    # Numeric imputer
    num_imp = SimpleImputer(strategy='median')
    df[num_cols] = num_imp.fit_transform(df[num_cols])

    # Categorical imputer
    cat_imp = SimpleImputer(strategy='most_frequent')
    df[cat_cols] = cat_imp.fit_transform(df[cat_cols])

    return df

# %%
# Apply the function to your dataframe
df = impute_vals(df, nums, cat)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   float64
#  4   Size            9659 non-null   float64
#  5   Installs        9659 non-null   float64
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9659 non-null   object
#  12  Android Ver     9659 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.0+ MB

# %%
#Scale the numeric data using the standard scaler
from sklearn.preprocessing import StandardScaler

# %%
#examine the magnitudes
df[nums].head()
# Out:
#    Rating   Reviews     Size    Installs  Price
# 0     4.1     159.0  19000.0     10000.0    0.0
# 1     3.9     967.0  14000.0    500000.0    0.0
# 2     4.7   87510.0   8700.0   5000000.0    0.0
# 3     4.5  215644.0  25000.0  50000000.0    0.0
# 4     4.3     967.0   2800.0    100000.0    0.0

# %%
#Examine the stats before scaling
df[nums].describe()
# Out:
#             Rating       Reviews           Size      Installs        Price
# count  9659.000000  9.659000e+03    9659.000000  9.659000e+03  9659.000000
# mean      4.192442  2.165926e+05   19319.357180  7.777507e+06     1.099299
# std       0.496397  1.831320e+06   20591.226479  5.375828e+07    16.852152
# min       1.000000  0.000000e+00      10.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01    5300.000000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02   12000.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04   25000.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09   400.000000

# %%
#create the scaler and the apply it
scaler = StandardScaler()
df[nums]=scaler.fit_transform(df[nums])

# %%
#examine the result of scaling
df[nums].head()
# Out:
#      Rating   Reviews      Size  Installs     Price
# 0 -0.186236 -0.118191 -0.015510 -0.144497 -0.065235
# 1 -0.589160 -0.117749 -0.258345 -0.135382 -0.065235
# 2  1.022536 -0.070490 -0.515749 -0.051669 -0.065235
# 3  0.619612 -0.000518  0.275891  0.785454 -0.065235
# 4  0.216688 -0.117749 -0.802294 -0.142823 -0.065235

# %%
df[nums].describe()
# Out:
#              Rating       Reviews          Size      Installs         Price
# count  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03
# mean   1.327072e-15 -2.942511e-18 -1.618381e-17 -2.942511e-18 -4.045952e-18
# std    1.000052e+00  1.000052e+00  1.000052e+00  1.000052e+00  1.000052e+00
# min   -6.431560e+00 -1.182774e-01 -9.377954e-01 -1.446830e-01 -6.523535e-02
# 25%   -3.876982e-01 -1.182638e-01 -6.808765e-01 -1.446644e-01 -6.523535e-02
# 50%    2.166880e-01 -1.177494e-01 -3.554784e-01 -1.428227e-01 -6.523535e-02
# 75%    6.196121e-01 -1.022221e-01  2.758911e-01 -1.260803e-01 -6.523535e-02
# max    1.626922e+00  4.256261e+01  3.918408e+00  1.845807e+01  2.367183e+01
